# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
# %cd ..
# Out:
# C:\Users\dimit\Desktop\MAchine Learning\final project\airbnb-price-prediction

# %%
from pathlib import Path

raw = Path("data")/"raw"

df_calendar    = pd.read_csv(raw/"calendar.csv.gz",  compression="gzip")
df_listings    = pd.read_csv(raw/"listings.csv.gz",  compression="gzip")
df_reviews     = pd.read_csv(raw/"reviews.csv.gz",   compression="gzip")
df_neigh_list  = pd.read_csv(raw/"neighbourhoods.zip", compression=None)
gdf_neigh_geo  = gpd.read_file(raw/"neighbourhoods.geojson")

print(df_calendar.shape, df_listings.shape, df_reviews.shape,
      df_neigh_list.shape, gdf_neigh_geo.shape)
# Out:
# (5085865, 7) (13945, 79) (588592, 6) (139, 2) (140, 3)

# %%
df_calendar.head()
# Out:
#    listing_id        date available   price  adjusted_price  minimum_nights  \
# 0      214518  2025-03-16         t  $51.00             NaN             3.0
# 1      214518  2025-03-17         t  $51.00             NaN             3.0
# 2      214518  2025-03-18         t  $51.00             NaN             3.0
# 3      214518  2025-03-19         t  $51.00             NaN             3.0
# 4      214518  2025-03-20         t  $51.00             NaN             3.0
#
#    maximum_nights
# 0            21.0
# 1            21.0
# 2            21.0
# 3            21.0
# 4            21.0

# %%
df_listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   3176   https://www.airbnb.com/rooms/3176  20250315152850   2025-03-16
# 1   9991   https://www.airbnb.com/rooms/9991  20250315152850   2025-03-16
# 2  14325  https://www.airbnb.com/rooms/14325  20250315152850   2025-03-16
# 3  16644  https://www.airbnb.com/rooms/16644  20250315152850   2025-03-16
# 4  17904  https://www.airbnb.com/rooms/17904  20250315152850   2025-03-16
#
#         source                                           name  \
# 0  city scrape                Fabulous Flat in great Location
# 1  city scrape            Geourgeous flat - outstanding views
# 2  city scrape            Studio Apartment in Prenzlauer Berg
# 3  city scrape             In the Heart of Berlin - Kreuzberg
# 4  city scrape  Beautiful Kreuzberg studio - 3 months minimum
#
#                                          description  \
# 0  This beautiful first floor apartment  is situa...
# ...

# %%
df_reviews.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0      323255  992614  2012-03-12      1354573        Renato
# 1        3176    4283  2009-06-20        21475        Milind
# 2        3176  134722  2010-11-07       263467        George
# 3        3176  144064  2010-11-24        76726      Patricia
# 4        3176  156702  2010-12-21       291657     Benedetta
#
#                                             comments
# 0  I had a relaxing time in Berlin, it looks so o...
# 1  excellent stay, i would highly recommend it. a...
# 2  Britta's apartment in Berlin is in a great are...
# 3  Fantastic, large place in good location. Only ...
# 4  L'appartamento di Britta è molto largo carino ...

# %%
df_neigh_list.head()
# Out:
#     neighbourhood_group        neighbourhood
# 0  Charlottenburg-Wilm.            Barstraße
# 1  Charlottenburg-Wilm.  Charlottenburg Nord
# 2  Charlottenburg-Wilm.  Düsseldorfer Straße
# 3  Charlottenburg-Wilm.      Forst Grunewald
# 4  Charlottenburg-Wilm.            Grunewald

# %%
gdf_neigh_geo.head()
# Out:
#                                neighbourhood   neighbourhood_group  \
# 0             Blankenfelde/Niederschönhausen                Pankow
# 1                             Helmholtzplatz                Pankow
# 2                         Wiesbadener Straße  Charlottenburg-Wilm.
# 3  Schmöckwitz/Karolinenhof/Rauchfangswerder    Treptow - Köpenick
# 4                                 Müggelheim    Treptow - Köpenick
#
#                                             geometry
# 0  MULTIPOLYGON (((13.41191 52.61487, 13.41183 52...
# 1  MULTIPOLYGON (((13.41405 52.54929, 13.41422 52...
# 2  MULTIPOLYGON (((13.30748 52.46788, 13.30743 52...
# 3  MULTIPOLYGON (((13.70973 52.3963, 13.70926 52....
# 4  MULTIPOLYGON (((13.73762 52.4085, 13.73773 52....

# %%
# %store df_listings
# %store df_calendar
# %store df_reviews
# %store df_neigh_list
# %store gdf_neigh_geo
# Out:
# Stored 'df_listings' (DataFrame)
# Stored 'df_calendar' (DataFrame)
# Stored 'df_reviews' (DataFrame)
# Stored 'df_neigh_list' (DataFrame)
# Stored 'gdf_neigh_geo' (GeoDataFrame)
